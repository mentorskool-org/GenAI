# %% [markdown]
# Reference: https://lablab.ai/event/nextgen-gpt-ai-hackathon/knightai/health-education-down-syndrome-chat

# %% [markdown]
# Github Repo: https://github.com/SamiaAlshehri/health_down_syndrome_chatbot

# %% [markdown]
# Demo: https://downsyndrome.streamlit.app/
