# %% [markdown]
# Refer this:
# 1. https://www.youtube.com/watch?v=jxmoJtFvoBI
# 2. https://www.unite.ai/mpt-30b-mosaicml-outshines-gpt-3-with-a-new-llm-to-push-the-boundaries-of-nlp/
#
# There are 2 models:
# 1. mosaicml/mpt-30b
# 2. mosaicml/mpt-30b-chat
# 3. mosaicml/mpt-30b-instruct
# 4. TheBloke/mpt-30B-GGML
