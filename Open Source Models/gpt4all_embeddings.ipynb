# %%
# %pip install gpt4all
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting gpt4all
#   Using cached gpt4all-2.0.2-py3-none-win_amd64.whl (7.4 MB)
# Requirement already satisfied: requests in c:\users\burha\mentorskool\self learning\genai\open source models\venv\lib\site-packages (from gpt4all) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\burha\mentorskool\self learning\genai\open source models\venv\lib\site-packages (from gpt4all) (4.66.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\burha\mentorskool\self learning\genai\open source models\venv\lib\site-packages (from requests->gpt4all) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\burha\mentorskool\self learning\genai\open source models\venv\lib\site-packages (from requests->gpt4all) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\burha\mentorskool\self learning\genai\open source models\venv\lib\site-packages (from requests->gpt4all) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\burha\mentorskool\self learning\genai\open source models\venv\lib\site-packages (from requests->gpt4all) (2023.11.17)
# Requirement already satisfied: colorama in c:\users\burha\mentorskool\self learning\genai\open source models\venv\lib\site-packages (from tqdm->gpt4all) (0.4.6)
# Installing collected packages: gpt4all
# Successfully installed gpt4all-2.0.2
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain.embeddings import GPT4AllEmbeddings

# %%
gpt4all_embd = GPT4AllEmbeddings()
# Out:
# 100%|██████████| 45.9M/45.9M [00:11<00:00, 3.91MiB/s]

# %%
text = "This is a test document."

# %%
query_result = gpt4all_embd.embed_query(text)

# %%
doc_result = gpt4all_embd.embed_documents([text])

# %%
# %pip uninstall gpt4all
